# %%
# !pip install implicit
# Out:
# Collecting implicit
#   Obtaining dependency information for implicit from https://files.pythonhosted.org/packages/cd/cc/deac70cae8cc32c9885d0cd73bc66e1b3cbea36ae7080b8c83995eaf5322/implicit-0.7.2-cp310-cp310-manylinux2014_x86_64.whl.metadata
#   Downloading implicit-0.7.2-cp310-cp310-manylinux2014_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.10/site-packages (from implicit) (1.24.3)
# Requirement already satisfied: scipy>=0.16 in /opt/conda/lib/python3.10/site-packages (from implicit) (1.11.4)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from implicit) (4.66.1)
# Requirement already satisfied: threadpoolctl in /opt/conda/lib/python3.10/site-packages (from implicit) (3.2.0)
# Downloading implicit-0.7.2-cp310-cp310-manylinux2014_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 49.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: implicit
# Successfully installed implicit-0.7.2

# %%
PATH = '/kaggle/input/otto-recsys-short/kaggle/working/'

# %%
import numpy as np
import pandas as pd

from scipy.sparse.linalg import svds
from scipy.sparse import csr_matrix
from sklearn.preprocessing import LabelEncoder

from tqdm.auto import tqdm
import gc

from implicit.gpu.als import AlternatingLeastSquares
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def encode_data(data, entities):
    data_ = data.copy()
    encoders = {}
    for e in entities:
        encoder = LabelEncoder()
        encoder.fit(data_[e])
        data_[e] = encoder.transform(data_[e])
        encoders[e] = encoder
    return data_, encoders

def get_table(n_elements):
    table = pd.DataFrame.from_dict(
        {i: None for i in range(n_elements)}, orient='index').reset_index()
    table = table.rename(columns={'index' : 'session', 0 : 'aid'})
    return table

# %% [markdown]
# ## ALS model 1
#
# Let's take default ALS method from implicit library.

# %%
df_clicks_train = pd.read_parquet(PATH + "/otto_exploded_dataset/clicks/train")
df_carts_train = pd.read_parquet(PATH + "/otto_exploded_dataset/carts/train")
df_orders_train = pd.read_parquet(PATH + "/otto_exploded_dataset/orders/train")

df_clicks_train['type'] = 1
df_carts_train['type'] = 1
df_orders_train['type'] = 1

# %% [markdown]
# ### Clicks

# %%
entities_clicks = ['session', 'aid']
training_clicks, encoders_clicks = encode_data(df_clicks_train, entities=entities_clicks)

num_session_clicks = training_clicks['session'].nunique()
num_aid_clicks = training_clicks['aid'].nunique()

csr_data_clicks = csr_matrix(
    (training_clicks['type'], (training_clicks.session, training_clicks.aid)),
    shape=(num_session_clicks, num_aid_clicks)
)

csr_data_clicks
# Out:
# <385470x774068 sparse matrix of type '<class 'numpy.int64'>'
# 	with 4162102 stored elements in Compressed Sparse Row format>

# %%
config_clicks = {
    'calculate_training_loss' : True, 
    'random_state' : 59 
}

als_model_clicks = AlternatingLeastSquares(
    calculate_training_loss=config_clicks['calculate_training_loss'], 
    random_state=config_clicks['random_state']
)

als_model_clicks.fit(csr_data_clicks, show_progress=True)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# !mkdir recs_clicks_als_1
# !ls
# Out:
# recs_clicks_als_1

# %%
batch_size = 2000
batch_count = (num_session_clicks + batch_size - 1) // batch_size
data_batches = []

all_users = np.arange(num_session_clicks)
for i, temp_user in tqdm(enumerate(range(batch_count))):

    if i <= batch_count - 1:
        temp_users = all_users[i*batch_size : (i+1)*batch_size]
    else:
        temp_users = all_users[i*batch_size : ]

    temp_table = get_table(len(temp_users))
    temp_table['session'] = encoders_clicks['session'].inverse_transform(temp_users)

    idxs = als_model_clicks.recommend(
        temp_users, 
        csr_data_clicks[temp_user], 
        N=2000, 
        filter_already_liked_items=False
    )[0]

    temp_table['aid'] = list(map(encoders_clicks['aid'].inverse_transform, idxs))
    temp_table.to_parquet(f'recs_clicks_als_1/part_{i}.parquet')
# Out:
# 0it [00:00, ?it/s]

# %%
# !zip -r "recs_clicks_als_1.zip" "recs_clicks_als_1"
# Out:
#   adding: recs_clicks_als_1/ (stored 0%)
#   adding: recs_clicks_als_1/part_12.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_33.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_53.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_108.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_11.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_94.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_156.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_162.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_92.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_115.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_177.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_191.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_159.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_89.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_118.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_22.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_27.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_181.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_133.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_192.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_141.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_40.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_78.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_19.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_105.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_160.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_122.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_25.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_80.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_45.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_87.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_119.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_138.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_21.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_170.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_55.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_14.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_76.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_179.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_152.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_135.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_163.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_13.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_175.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_51.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_46.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_124.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_125.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_91.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_90.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_15.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_17.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_184.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_81.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_134.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_102.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_149.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_155.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_42.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_176.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_171.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_103.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_93.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_121.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_44.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_62.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_20.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_188.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_97.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_139.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_32.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_7.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_168.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_158.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_100.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_34.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_142.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_113.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_182.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_143.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_123.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_10.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_64.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_39.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_48.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_165.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_69.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_56.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_151.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_140.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_0.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_71.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_74.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_26.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_173.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_117.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_50.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_6.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_148.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_154.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_30.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_150.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_18.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_107.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_8.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_1.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_185.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_187.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_63.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_114.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_36.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_130.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_84.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_146.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_66.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_2.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_61.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_29.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_101.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_104.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_116.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_57.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_109.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_189.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_169.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_106.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_180.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_16.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_41.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_77.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_183.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_128.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_35.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_136.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_131.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_111.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_60.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_86.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_126.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_52.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_73.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_59.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_85.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_37.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_96.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_98.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_157.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_23.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_178.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_4.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_95.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_99.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_3.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_70.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_172.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_5.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_43.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_65.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_67.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_38.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_58.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_82.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_147.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_79.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_190.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_49.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_28.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_112.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_166.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_174.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_47.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_127.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_167.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_132.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_83.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_24.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_75.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_110.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_54.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_153.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_88.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_129.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_72.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_137.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_161.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_144.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_9.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_120.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_68.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_31.parquet (deflated 6%)
#   adding: recs_clicks_als_1/part_145.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_164.parquet (deflated 5%)
#   adding: recs_clicks_als_1/part_186.parquet (deflated 6%)

# %% [markdown]
# ### Carts

# %%
entities_carts = ['session', 'aid']
training_carts, encoders_carts = encode_data(df_carts_train, entities=entities_carts)

num_session_carts = training_carts['session'].nunique()
num_aid_carts = training_carts['aid'].nunique()

csr_data_carts = csr_matrix(
    (training_carts['type'], (training_carts.session, training_carts.aid)),
    shape=(num_session_carts, num_aid_carts)
)

csr_data_carts
# Out:
# <123891x196951 sparse matrix of type '<class 'numpy.int64'>'
# 	with 427040 stored elements in Compressed Sparse Row format>

# %%
config_carts = {
    'calculate_training_loss' : True, 
    'random_state' : 59 
}

als_model_carts = AlternatingLeastSquares(
    calculate_training_loss=config_carts['calculate_training_loss'], 
    random_state=config_carts['random_state']
)

als_model_carts.fit(csr_data_carts, show_progress=True)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# !mkdir recs_carts_als_1
# !ls
# Out:
# recs_carts_als_1  recs_clicks_als_1  recs_clicks_als_1.zip

# %%
batch_size = 2000
batch_count = (num_session_carts + batch_size - 1) // batch_size
data_batches = []

all_users = np.arange(num_session_carts)
for i, temp_user in tqdm(enumerate(range(batch_count))):

    if i <= batch_count - 1:
        temp_users = all_users[i*batch_size : (i+1)*batch_size]
    else:
        temp_users = all_users[i*batch_size : ]

    temp_table = get_table(len(temp_users))
    temp_table['session'] = encoders_carts['session'].inverse_transform(temp_users)
        
    idxs = als_model_carts.recommend(
        temp_users, 
        csr_data_carts[temp_user], 
        N=2000, 
        filter_already_liked_items=False
    )[0]

    temp_table['aid'] = list(map(encoders_carts['aid'].inverse_transform, idxs))
    temp_table.to_parquet(f'recs_carts_als_1/part_{i}.parquet')
# Out:
# 0it [00:00, ?it/s]

# %%
# !zip -r "recs_carts_als_1.zip" "recs_carts_als_1"
# Out:
#   adding: recs_carts_als_1/ (stored 0%)
#   adding: recs_carts_als_1/part_12.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_33.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_53.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_11.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_22.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_27.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_40.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_19.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_25.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_45.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_21.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_55.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_14.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_13.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_51.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_46.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_15.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_17.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_42.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_44.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_20.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_32.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_7.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_34.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_10.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_39.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_48.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_56.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_0.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_26.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_50.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_6.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_30.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_18.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_8.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_1.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_36.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_2.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_61.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_29.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_57.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_16.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_41.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_35.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_60.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_52.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_59.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_37.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_23.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_4.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_3.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_5.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_43.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_38.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_58.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_49.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_28.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_47.parquet (deflated 8%)
#   adding: recs_carts_als_1/part_24.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_54.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_9.parquet (deflated 7%)
#   adding: recs_carts_als_1/part_31.parquet (deflated 7%)

# %% [markdown]
# ### Orders

# %%
entities_orders = ['session', 'aid']
training_orders, encoders_orders = encode_data(df_orders_train, entities=entities_orders)

num_session_orders = training_orders['session'].nunique()
num_aid_orders = training_orders['aid'].nunique()

csr_data_orders = csr_matrix(
    (training_orders['type'], (training_orders.session, training_orders.aid)),
    shape=(num_session_orders, num_aid_orders)
)

csr_data_orders
# Out:
# <55845x79824 sparse matrix of type '<class 'numpy.int64'>'
# 	with 140831 stored elements in Compressed Sparse Row format>

# %%
config_orders = {
    'calculate_training_loss' : True, 
    'random_state' : 59 
}

als_model_orders = AlternatingLeastSquares(
    calculate_training_loss=config_orders['calculate_training_loss'], 
    random_state=config_orders['random_state']
)

als_model_orders.fit(csr_data_orders, show_progress=True)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# !mkdir recs_orders_als_1
# !ls
# Out:
# recs_carts_als_1      recs_clicks_als_1      recs_orders_als_1
# recs_carts_als_1.zip  recs_clicks_als_1.zip

# %%
batch_size = 2000
batch_count = (num_session_orders + batch_size - 1) // batch_size
data_batches = []

all_users = np.arange(num_session_orders)
for i, temp_user in tqdm(enumerate(range(batch_count))):

    if i <= batch_count - 1:
        temp_users = all_users[i*batch_size : (i+1)*batch_size]
    else:
        temp_users = all_users[i*batch_size : ]

    temp_table = get_table(len(temp_users))
    temp_table['session'] = encoders_orders['session'].inverse_transform(temp_users)
        
    idxs = als_model_orders.recommend(
        temp_users, 
        csr_data_orders[temp_user], 
        N=2000, 
        filter_already_liked_items=False
    )[0]

    temp_table['aid'] = list(map(encoders_orders['aid'].inverse_transform, idxs))
    temp_table.to_parquet(f'recs_orders_als_1/part_{i}.parquet')
# Out:
# 0it [00:00, ?it/s]

# %%
# !zip -r "recs_orders_als_1.zip" "recs_orders_als_1"
# Out:
#   adding: recs_orders_als_1/ (stored 0%)
#   adding: recs_orders_als_1/part_12.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_11.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_22.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_27.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_19.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_25.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_21.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_14.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_13.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_15.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_17.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_20.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_7.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_10.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_0.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_26.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_6.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_18.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_8.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_1.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_2.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_16.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_23.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_4.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_3.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_5.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_24.parquet (deflated 2%)
#   adding: recs_orders_als_1/part_9.parquet (deflated 2%)

# %% [markdown]
# ## ALS model 2
#
# Let's preprocess our data firstly and then use standart ALS.

# %%
df_clicks_train = pd.read_parquet(PATH + "/otto_exploded_dataset/clicks/train")
df_carts_train = pd.read_parquet(PATH + "/otto_exploded_dataset/carts/train")
df_orders_train = pd.read_parquet(PATH + "/otto_exploded_dataset/orders/train")

df_clicks_train['type'] = 1
df_carts_train['type'] = 1
df_orders_train['type'] = 1

# %% [markdown]
# ### Clicks

# %%
# Data preprocess

min_ts, max_ts  = df_clicks_train['ts'].min(), df_clicks_train['ts'].max()
df_clicks_train['weight'] = np.exp(
    0.5 * (df_clicks_train['ts'] - min_ts) / (max_ts - min_ts))

scale_factor = 10
df_clicks_train['weighted_type'] = scale_factor * df_clicks_train['type'] * df_clicks_train['weight']

# %%
entities_clicks = ['session', 'aid']
training_clicks, encoders_clicks = encode_data(df_clicks_train, entities=entities_clicks)

num_session_clicks = training_clicks['session'].nunique()
num_aid_clicks = training_clicks['aid'].nunique()

csr_data_clicks = csr_matrix(
    (training_clicks['weighted_type'], (training_clicks.session, training_clicks.aid)),
    shape=(num_session_clicks, num_aid_clicks)
)

csr_data_clicks
# Out:
# <385470x774068 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4162102 stored elements in Compressed Sparse Row format>

# %%
config_clicks = {
    'calculate_training_loss' : True, 
    'random_state' : 59 
}

als_model_clicks = AlternatingLeastSquares(
    calculate_training_loss=config_clicks['calculate_training_loss'], 
    random_state=config_clicks['random_state']
)

als_model_clicks.fit(csr_data_clicks, show_progress=True)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# !mkdir recs_clicks_als_2
# !ls
# Out:
# recs_carts_als_1      recs_clicks_als_1.zip  recs_orders_als_1.zip
# recs_carts_als_1.zip  recs_clicks_als_2
# recs_clicks_als_1     recs_orders_als_1

# %%
batch_size = 2000
batch_count = (num_session_clicks + batch_size - 1) // batch_size
data_batches = []

all_users = np.arange(num_session_clicks)
for i, temp_user in tqdm(enumerate(range(batch_count))):

    if i <= batch_count - 1:
        temp_users = all_users[i*batch_size : (i+1)*batch_size]
    else:
        temp_users = all_users[i*batch_size : ]

    temp_table = get_table(len(temp_users))
    temp_table['session'] = encoders_clicks['session'].inverse_transform(temp_users)

    idxs = als_model_clicks.recommend(
        temp_users, 
        csr_data_clicks[temp_user], 
        N=2000, 
        filter_already_liked_items=False
    )[0]

    temp_table['aid'] = list(map(encoders_clicks['aid'].inverse_transform, idxs))
    temp_table.to_parquet(f'recs_clicks_als_2/part_{i}.parquet')
# Out:
# 0it [00:00, ?it/s]

# %%
# !zip -r "recs_clicks_als_2.zip" "recs_clicks_als_2"
# Out:
#   adding: recs_clicks_als_2/ (stored 0%)
#   adding: recs_clicks_als_2/part_12.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_33.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_53.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_108.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_11.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_94.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_156.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_162.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_92.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_115.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_177.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_191.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_159.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_89.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_118.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_22.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_27.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_181.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_133.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_192.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_141.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_40.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_78.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_19.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_105.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_160.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_122.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_25.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_80.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_45.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_87.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_119.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_138.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_21.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_170.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_55.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_14.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_76.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_179.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_152.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_135.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_163.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_13.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_175.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_51.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_46.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_124.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_125.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_91.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_90.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_15.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_17.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_184.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_81.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_134.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_102.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_149.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_155.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_42.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_176.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_171.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_103.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_93.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_121.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_44.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_62.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_20.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_188.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_97.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_139.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_32.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_7.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_168.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_158.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_100.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_34.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_142.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_113.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_182.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_143.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_123.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_10.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_64.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_39.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_48.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_165.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_69.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_56.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_151.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_140.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_0.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_71.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_74.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_26.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_173.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_117.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_50.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_6.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_148.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_154.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_30.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_150.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_18.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_107.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_8.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_1.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_185.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_187.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_63.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_114.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_36.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_130.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_84.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_146.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_66.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_2.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_61.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_29.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_101.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_104.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_116.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_57.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_109.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_189.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_169.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_106.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_180.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_16.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_41.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_77.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_183.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_128.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_35.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_136.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_131.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_111.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_60.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_86.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_126.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_52.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_73.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_59.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_85.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_37.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_96.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_98.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_157.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_23.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_178.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_4.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_95.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_99.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_3.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_70.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_172.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_5.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_43.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_65.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_67.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_38.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_58.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_82.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_147.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_79.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_190.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_49.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_28.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_112.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_166.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_174.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_47.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_127.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_167.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_132.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_83.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_24.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_75.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_110.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_54.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_153.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_88.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_129.parquet (deflated 2%)
#   adding: recs_clicks_als_2/part_72.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_137.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_161.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_144.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_9.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_120.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_68.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_31.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_145.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_164.parquet (deflated 3%)
#   adding: recs_clicks_als_2/part_186.parquet (deflated 3%)

# %% [markdown]
# ### Carts

# %%
# Data preprocess

min_ts, max_ts  = df_carts_train['ts'].min(), df_carts_train['ts'].max()
df_carts_train['weight'] = np.exp(
    0.5 * (df_carts_train['ts'] - min_ts) / (max_ts - min_ts))

scale_factor = 10
df_carts_train['weighted_type'] = scale_factor * df_carts_train['type'] * df_carts_train['weight']

# %%
entities_carts = ['session', 'aid']
training_carts, encoders_carts = encode_data(df_carts_train, entities=entities_carts)

num_session_carts = training_carts['session'].nunique()
num_aid_carts = training_carts['aid'].nunique()

csr_data_carts = csr_matrix(
    (training_carts['weighted_type'], (training_carts.session, training_carts.aid)),
    shape=(num_session_carts, num_aid_carts)
)

csr_data_carts
# Out:
# <123891x196951 sparse matrix of type '<class 'numpy.float64'>'
# 	with 427040 stored elements in Compressed Sparse Row format>

# %%
config_carts = {
    'calculate_training_loss' : True, 
    'random_state' : 59 
}

als_model_carts = AlternatingLeastSquares(
    calculate_training_loss=config_carts['calculate_training_loss'], 
    random_state=config_carts['random_state']
)

als_model_carts.fit(csr_data_carts, show_progress=True)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# !mkdir recs_carts_als_2
# !ls
# Out:
# recs_carts_als_1      recs_clicks_als_1      recs_clicks_als_2.zip
# recs_carts_als_1.zip  recs_clicks_als_1.zip  recs_orders_als_1
# recs_carts_als_2      recs_clicks_als_2      recs_orders_als_1.zip

# %%
batch_size = 2000
batch_count = (num_session_carts + batch_size - 1) // batch_size
data_batches = []

all_users = np.arange(num_session_carts)
for i, temp_user in tqdm(enumerate(range(batch_count))):

    if i <= batch_count - 1:
        temp_users = all_users[i*batch_size : (i+1)*batch_size]
    else:
        temp_users = all_users[i*batch_size : ]

    temp_table = get_table(len(temp_users))
    temp_table['session'] = encoders_carts['session'].inverse_transform(temp_users)
        
    idxs = als_model_carts.recommend(
        temp_users, 
        csr_data_carts[temp_user], 
        N=2000, 
        filter_already_liked_items=False
    )[0]

    temp_table['aid'] = list(map(encoders_carts['aid'].inverse_transform, idxs))
    temp_table.to_parquet(f'recs_carts_als_2/part_{i}.parquet')
# Out:
# 0it [00:00, ?it/s]

# %%
# !zip -r "recs_carts_als_2.zip" "recs_carts_als_2"
# Out:
#   adding: recs_carts_als_2/ (stored 0%)
#   adding: recs_carts_als_2/part_12.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_33.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_53.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_11.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_22.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_27.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_40.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_19.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_25.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_45.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_21.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_55.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_14.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_13.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_51.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_46.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_15.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_17.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_42.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_44.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_20.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_32.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_7.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_34.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_10.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_39.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_48.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_56.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_0.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_26.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_50.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_6.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_30.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_18.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_8.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_1.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_36.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_2.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_61.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_29.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_57.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_16.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_41.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_35.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_60.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_52.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_59.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_37.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_23.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_4.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_3.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_5.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_43.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_38.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_58.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_49.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_28.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_47.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_24.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_54.parquet (deflated 6%)
#   adding: recs_carts_als_2/part_9.parquet (deflated 5%)
#   adding: recs_carts_als_2/part_31.parquet (deflated 6%)

# %% [markdown]
# ### Orders

# %%
# Data preprocess

min_ts, max_ts  = df_orders_train['ts'].min(), df_orders_train['ts'].max()
df_orders_train['weight'] = np.exp(
    0.5 * (df_orders_train['ts'] - min_ts) / (max_ts - min_ts))

scale_factor = 10
df_orders_train['weighted_type'] = scale_factor * df_orders_train['type'] * df_orders_train['weight']

# %%
entities_orders = ['session', 'aid']
training_orders, encoders_orders = encode_data(df_orders_train, entities=entities_orders)

num_session_orders = training_orders['session'].nunique()
num_aid_orders = training_orders['aid'].nunique()

csr_data_orders = csr_matrix(
    (training_orders['weighted_type'], (training_orders.session, training_orders.aid)),
    shape=(num_session_orders, num_aid_orders)
)

csr_data_orders
# Out:
# <55845x79824 sparse matrix of type '<class 'numpy.float64'>'
# 	with 140831 stored elements in Compressed Sparse Row format>

# %%
config_orders = {
    'calculate_training_loss' : True, 
    'random_state' : 59 
}

als_model_orders = AlternatingLeastSquares(
    calculate_training_loss=config_orders['calculate_training_loss'], 
    random_state=config_orders['random_state']
)

als_model_orders.fit(csr_data_orders, show_progress=True)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# !mkdir recs_orders_als_2
# !ls
# Out:
# recs_carts_als_1      recs_clicks_als_1      recs_orders_als_1
# recs_carts_als_1.zip  recs_clicks_als_1.zip  recs_orders_als_1.zip
# recs_carts_als_2      recs_clicks_als_2      recs_orders_als_2
# recs_carts_als_2.zip  recs_clicks_als_2.zip

# %%
batch_size = 2000
batch_count = (num_session_orders + batch_size - 1) // batch_size
data_batches = []

all_users = np.arange(num_session_orders)
for i, temp_user in tqdm(enumerate(range(batch_count))):

    if i <= batch_count - 1:
        temp_users = all_users[i*batch_size : (i+1)*batch_size]
    else:
        temp_users = all_users[i*batch_size : ]

    temp_table = get_table(len(temp_users))
    temp_table['session'] = encoders_orders['session'].inverse_transform(temp_users)

    idxs = als_model_orders.recommend(
        temp_users,
        csr_data_orders[temp_user],
        N=2000,
        filter_already_liked_items=False
    )[0]

    temp_table['aid'] = list(map(encoders_orders['aid'].inverse_transform, idxs))
    temp_table.to_parquet(f'recs_orders_als_2/part_{i}.parquet')
# Out:
# 0it [00:00, ?it/s]

# %%
# !zip -r "recs_orders_als_2.zip" "recs_orders_als_2"
# Out:
#   adding: recs_orders_als_2/ (stored 0%)
#   adding: recs_orders_als_2/part_12.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_11.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_22.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_27.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_19.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_25.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_21.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_14.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_13.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_15.parquet (deflated 3%)
#   adding: recs_orders_als_2/part_17.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_20.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_7.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_10.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_0.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_26.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_6.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_18.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_8.parquet (deflated 3%)
#   adding: recs_orders_als_2/part_1.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_2.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_16.parquet (deflated 3%)
#   adding: recs_orders_als_2/part_23.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_4.parquet (deflated 2%)
#   adding: recs_orders_als_2/part_3.parquet (deflated 3%)
#   adding: recs_orders_als_2/part_5.parquet (deflated 3%)
#   adding: recs_orders_als_2/part_24.parquet (deflated 3%)
#   adding: recs_orders_als_2/part_9.parquet (deflated 2%)

# %% [markdown]
# ## ALS model 3
#
# Let's add to previous model some additional constraints of the data.

# %%
df_clicks_train = pd.read_parquet(PATH + "/otto_exploded_dataset/clicks/train")
df_carts_train = pd.read_parquet(PATH + "/otto_exploded_dataset/carts/train")
df_orders_train = pd.read_parquet(PATH + "/otto_exploded_dataset/orders/train")

df_clicks_train['type'] = 1
df_carts_train['type'] = 1
df_orders_train['type'] = 1

# %% [markdown]
# ### Clicks

# %%
# Data preprocess
min_ts, max_ts  = df_clicks_train['ts'].min(), df_clicks_train['ts'].max()
df_clicks_train['weight'] = np.exp(
    0.5 * (df_clicks_train['ts'] - min_ts) / (max_ts - min_ts))

scale_factor = 10
df_clicks_train['weighted_type'] = scale_factor * df_clicks_train['type'] * df_clicks_train['weight']

# %%
entities_clicks = ['session', 'aid']
training_clicks, encoders_clicks = encode_data(df_clicks_train, entities=entities_clicks)

num_session_clicks = training_clicks['session'].nunique()
num_aid_clicks = training_clicks['aid'].nunique()

csr_data_clicks = csr_matrix(
    (training_clicks['weighted_type'], (training_clicks.session, training_clicks.aid)),
    shape=(num_session_clicks, num_aid_clicks)
)

csr_data_clicks.data = np.clip(csr_data_clicks.data, 0, 20)

csr_data_clicks
# Out:
# <385470x774068 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4162102 stored elements in Compressed Sparse Row format>

# %%
config_clicks = {
    'calculate_training_loss' : True, 
    'random_state' : 59 
}

als_model_clicks = AlternatingLeastSquares(
    calculate_training_loss=config_clicks['calculate_training_loss'], 
    random_state=config_clicks['random_state']
)

als_model_clicks.fit(csr_data_clicks, show_progress=True)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# !mkdir recs_clicks_als_3
# !ls
# Out:
# recs_carts_als_1      recs_clicks_als_1.zip  recs_orders_als_1.zip
# recs_carts_als_1.zip  recs_clicks_als_2      recs_orders_als_2
# recs_carts_als_2      recs_clicks_als_2.zip  recs_orders_als_2.zip
# recs_carts_als_2.zip  recs_clicks_als_3
# recs_clicks_als_1     recs_orders_als_1

# %%
batch_size = 2000
batch_count = (num_session_clicks + batch_size - 1) // batch_size
data_batches = []

all_users = np.arange(num_session_clicks)
for i, temp_user in tqdm(enumerate(range(batch_count))):

    if i <= batch_count - 1:
        temp_users = all_users[i*batch_size : (i+1)*batch_size]
    else:
        temp_users = all_users[i*batch_size : ]

    temp_table = get_table(len(temp_users))
    temp_table['session'] = encoders_clicks['session'].inverse_transform(temp_users)

    idxs = als_model_clicks.recommend(
        temp_users, 
        csr_data_clicks[temp_user], 
        N=2000, 
        filter_already_liked_items=False
    )[0]

    temp_table['aid'] = list(map(encoders_clicks['aid'].inverse_transform, idxs))
    temp_table.to_parquet(f'recs_clicks_als_3/part_{i}.parquet')
# Out:
# 0it [00:00, ?it/s]

# %%
# !zip -r "recs_clicks_als_3.zip" "recs_clicks_als_3"
# Out:
#   adding: recs_clicks_als_3/ (stored 0%)
#   adding: recs_clicks_als_3/part_12.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_33.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_53.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_108.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_11.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_94.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_156.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_162.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_92.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_115.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_177.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_191.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_159.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_89.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_118.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_22.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_27.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_181.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_133.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_192.parquet (deflated 5%)
#   adding: recs_clicks_als_3/part_141.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_40.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_78.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_19.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_105.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_160.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_122.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_25.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_80.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_45.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_87.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_119.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_138.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_21.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_170.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_55.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_14.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_76.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_179.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_152.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_135.parquet (deflated 3%)
#   adding: recs_clicks_als_3/part_163.parquet (deflated 3%)
#   adding: recs_clicks_als_3/part_13.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_175.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_51.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_46.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_124.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_125.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_91.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_90.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_15.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_17.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_184.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_81.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_134.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_102.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_149.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_155.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_42.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_176.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_171.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_103.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_93.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_121.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_44.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_62.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_20.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_188.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_97.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_139.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_32.parquet (deflated 3%)
#   adding: recs_clicks_als_3/part_7.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_168.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_158.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_100.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_34.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_142.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_113.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_182.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_143.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_123.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_10.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_64.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_39.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_48.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_165.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_69.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_56.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_151.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_140.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_0.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_71.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_74.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_26.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_173.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_117.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_50.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_6.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_148.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_154.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_30.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_150.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_18.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_107.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_8.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_1.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_185.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_187.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_63.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_114.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_36.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_130.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_84.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_146.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_66.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_2.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_61.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_29.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_101.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_104.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_116.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_57.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_109.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_189.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_169.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_106.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_180.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_16.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_41.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_77.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_183.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_128.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_35.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_136.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_131.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_111.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_60.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_86.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_126.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_52.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_73.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_59.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_85.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_37.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_96.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_98.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_157.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_23.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_178.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_4.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_95.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_99.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_3.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_70.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_172.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_5.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_43.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_65.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_67.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_38.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_58.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_82.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_147.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_79.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_190.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_49.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_28.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_112.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_166.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_174.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_47.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_127.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_167.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_132.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_83.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_24.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_75.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_110.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_54.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_153.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_88.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_129.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_72.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_137.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_161.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_144.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_9.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_120.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_68.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_31.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_145.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_164.parquet (deflated 4%)
#   adding: recs_clicks_als_3/part_186.parquet (deflated 4%)

# %% [markdown]
# ### Carts

# %%
# Data preprocess

min_ts, max_ts  = df_carts_train['ts'].min(), df_carts_train['ts'].max()
df_carts_train['weight'] = np.exp(
    0.5 * (df_carts_train['ts'] - min_ts) / (max_ts - min_ts))

scale_factor = 10
df_carts_train['weighted_type'] = scale_factor * df_carts_train['type'] * df_carts_train['weight']

# %%
entities_carts = ['session', 'aid']
training_carts, encoders_carts = encode_data(df_carts_train, entities=entities_carts)

num_session_carts = training_carts['session'].nunique()
num_aid_carts = training_carts['aid'].nunique()

csr_data_carts = csr_matrix(
    (training_carts['weighted_type'], (training_carts.session, training_carts.aid)),
    shape=(num_session_carts, num_aid_carts)
)

csr_data_carts.data = np.clip(csr_data_carts.data, 0, 20)

csr_data_carts
# Out:
# <123891x196951 sparse matrix of type '<class 'numpy.float64'>'
# 	with 427040 stored elements in Compressed Sparse Row format>

# %%
config_carts = {
    'calculate_training_loss' : True, 
    'random_state' : 59 
}

als_model_carts = AlternatingLeastSquares(
    calculate_training_loss=config_carts['calculate_training_loss'], 
    random_state=config_carts['random_state']
)

als_model_carts.fit(csr_data_carts, show_progress=True)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# !mkdir recs_carts_als_3
# !ls
# Out:
# recs_carts_als_1      recs_clicks_als_1      recs_clicks_als_3.zip
# recs_carts_als_1.zip  recs_clicks_als_1.zip  recs_orders_als_1
# recs_carts_als_2      recs_clicks_als_2      recs_orders_als_1.zip
# recs_carts_als_2.zip  recs_clicks_als_2.zip  recs_orders_als_2
# recs_carts_als_3      recs_clicks_als_3      recs_orders_als_2.zip

# %%
batch_size = 2000
batch_count = (num_session_carts + batch_size - 1) // batch_size
data_batches = []

all_users = np.arange(num_session_carts)
for i, temp_user in tqdm(enumerate(range(batch_count))):

    if i <= batch_count - 1:
        temp_users = all_users[i*batch_size : (i+1)*batch_size]
    else:
        temp_users = all_users[i*batch_size : ]

    temp_table = get_table(len(temp_users))
    temp_table['session'] = encoders_carts['session'].inverse_transform(temp_users)
        
    idxs = als_model_carts.recommend(
        temp_users, 
        csr_data_carts[temp_user], 
        N=2000, 
        filter_already_liked_items=False
    )[0]

    temp_table['aid'] = list(map(encoders_carts['aid'].inverse_transform, idxs))
    temp_table.to_parquet(f'recs_carts_als_3/part_{i}.parquet')
# Out:
# 0it [00:00, ?it/s]

# %%
# !zip -r "recs_carts_als_3.zip" "recs_carts_als_3"
# Out:
#   adding: recs_carts_als_3/ (stored 0%)
#   adding: recs_carts_als_3/part_12.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_33.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_53.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_11.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_22.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_27.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_40.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_19.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_25.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_45.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_21.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_55.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_14.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_13.parquet (deflated 6%)
#   adding: recs_carts_als_3/part_51.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_46.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_15.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_17.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_42.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_44.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_20.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_32.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_7.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_34.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_10.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_39.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_48.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_56.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_0.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_26.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_50.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_6.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_30.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_18.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_8.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_1.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_36.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_2.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_61.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_29.parquet (deflated 6%)
#   adding: recs_carts_als_3/part_57.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_16.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_41.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_35.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_60.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_52.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_59.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_37.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_23.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_4.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_3.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_5.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_43.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_38.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_58.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_49.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_28.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_47.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_24.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_54.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_9.parquet (deflated 5%)
#   adding: recs_carts_als_3/part_31.parquet (deflated 5%)

# %% [markdown]
# ### Orders

# %%
# Data preprocess

min_ts, max_ts  = df_orders_train['ts'].min(), df_orders_train['ts'].max()
df_orders_train['weight'] = np.exp(
    0.5 * (df_orders_train['ts'] - min_ts) / (max_ts - min_ts))

scale_factor = 10
df_orders_train['weighted_type'] = scale_factor * df_orders_train['type'] * df_orders_train['weight']

# %%
entities_orders = ['session', 'aid']
training_orders, encoders_orders = encode_data(df_orders_train, entities=entities_orders)

num_session_orders = training_orders['session'].nunique()
num_aid_orders = training_orders['aid'].nunique()

csr_data_orders = csr_matrix(
    (training_orders['weighted_type'], (training_orders.session, training_orders.aid)),
    shape=(num_session_orders, num_aid_orders)
)

csr_data_orders.data = np.clip(csr_data_orders.data, 0, 20)

csr_data_orders
# Out:
# <55845x79824 sparse matrix of type '<class 'numpy.float64'>'
# 	with 140831 stored elements in Compressed Sparse Row format>

# %%
config_orders = {
    'calculate_training_loss' : True, 
    'random_state' : 59 
}

als_model_orders = AlternatingLeastSquares(
    calculate_training_loss=config_orders['calculate_training_loss'], 
    random_state=config_orders['random_state']
)

als_model_orders.fit(csr_data_orders, show_progress=True)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
# !mkdir recs_orders_als_3
# !ls
# Out:
# recs_carts_als_1      recs_clicks_als_1      recs_orders_als_1
# recs_carts_als_1.zip  recs_clicks_als_1.zip  recs_orders_als_1.zip
# recs_carts_als_2      recs_clicks_als_2      recs_orders_als_2
# recs_carts_als_2.zip  recs_clicks_als_2.zip  recs_orders_als_2.zip
# recs_carts_als_3      recs_clicks_als_3      recs_orders_als_3
# recs_carts_als_3.zip  recs_clicks_als_3.zip

# %%
batch_size = 2000
batch_count = (num_session_orders + batch_size - 1) // batch_size
data_batches = []

all_users = np.arange(num_session_orders)
for i, temp_user in tqdm(enumerate(range(batch_count))):

    if i <= batch_count - 1:
        temp_users = all_users[i*batch_size : (i+1)*batch_size]
    else:
        temp_users = all_users[i*batch_size : ]

    temp_table = get_table(len(temp_users))
    temp_table['session'] = encoders_orders['session'].inverse_transform(temp_users)

    idxs = als_model_orders.recommend(
        temp_users,
        csr_data_orders[temp_user],
        N=2000,
        filter_already_liked_items=False
    )[0]

    temp_table['aid'] = list(map(encoders_orders['aid'].inverse_transform, idxs))
    temp_table.to_parquet(f'recs_orders_als_3/part_{i}.parquet')
# Out:
# 0it [00:00, ?it/s]

# %%
# !zip -r "recs_orders_als_3.zip" "recs_orders_als_3"
# Out:
#   adding: recs_orders_als_3/ (stored 0%)
#   adding: recs_orders_als_3/part_12.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_11.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_22.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_27.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_19.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_25.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_21.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_14.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_13.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_15.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_17.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_20.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_7.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_10.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_0.parquet (deflated 3%)
#   adding: recs_orders_als_3/part_26.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_6.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_18.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_8.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_1.parquet (deflated 3%)
#   adding: recs_orders_als_3/part_2.parquet (deflated 3%)
#   adding: recs_orders_als_3/part_16.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_23.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_4.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_3.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_5.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_24.parquet (deflated 4%)
#   adding: recs_orders_als_3/part_9.parquet (deflated 4%)
